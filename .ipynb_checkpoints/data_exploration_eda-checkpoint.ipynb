# %% [markdown]
# # Exploratory Data Analysis for Hair Type Classification

# %% [markdown]
# **Goals of This Notebook:**
# - Conduct a structured exploratory analysis of the Hair Type dataset to understand its characteristics before building any classification or clustering models
#
# - Examine class distributions, visual variability, image statistcs, basic texture patterns that may relate to curl tightness
#
# - These insights are the foundation to the later stages of the project: (1) training VGG16-based CNN to classify the four broad hair categories, and (2) extracting texture and curl features to explore finer curl patterned (similiar to the Andrew Walker types) emerge through unsupervised clustering

# %% [markdown]
# #### Note: Some cells include working notes and ideas intended for my report

# %%
# download kaggle dataset
import kagglehub
kaggle_hairtype_dataset_path = kagglehub.dataset_download('kavyasreeb/hair-type-dataset')

print("Dataset downloaded at: ", kaggle_hairtype_dataset_path )

data_dir = kaggle_hairtype_dataset_path
# Out:
# Dataset downloaded at:  C:\Users\nisa2\.cache\kagglehub\datasets\kavyasreeb\hair-type-dataset\versions\1

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\nisa2\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nisa2\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\nisa2\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\nisa2\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\nisa2\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nisa2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nisa2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nisa2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nisa2\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.4.1)
# Requirement already satisfied: pillow in c:\users\nisa2\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (10.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nisa2\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nisa2\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\nisa2\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nisa2\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nisa2\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.version)
# Out:
# 3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]

# %%
# libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import os
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import tensorflow as tf
#       5 import seaborn as sns
#       6 import os
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\nisa2\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
# random seeds

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Dataset Exploration (EDA)

# %% [markdown]
# ## Load Dataset & Inspect Metadata
#
# - for "Dataset Description" of report

# %%
# load dataset
i

# see labels

# %%
# dataset path

# print folder structure

# %% [markdown]
# ## Dataset Overview
#
# - good for Experiment Settings and Benchmark Data section of report

# %%
# total number of images

# number of images per class

# class imbalance ratio

# %%
# bar chart visualization of class distribution
sns.countplot(data=df, x='label')
plt.title("Class Distribution")

# %% [markdown]
# ## Display Sample Images
#
# Why:
# - See Data diversity
# - see lighting/background issues (can be mentioned in report)
# - see if curliness is visually apparent
#
# figures would go well in report
#
# (delete or rewrite later)

# %%
# One figure per class
# display 10 images per class

# %% [markdown]
# ## Image Dimensions & Aspect Ratio
#
# - Good for justifiing resizing decisions before sending images into VGG16

# %%
# load images

# print shapes (height, width, channels)

# count frequency of unique dimensions

# visualize histogram of aspect ratios

# %% [markdown]
# ## Image Statisitics (to analyze class differences for CNN)
#
#  - Average brightness
#  - Average color histograms per channel
#  - hair-region pixel proportion
#
#  helps answer these if want to put in report:
#  - does hair type correlate with brightness or color distributions
#  - do curly/kinky images have different texture intensity

# %%
# convert sample images to grayscale

# %%
# compute average brightness per image

# %%
# plot brightness distribution per image

# %%
# compute color histograms for RGB channels

# %% [markdown]
# ## Edge Detection Exploration
#
# This is an insight into hair texture
#
# Insight goals:
# - curly and kinky hair have more edges
# - straight hair have smoother regions
#
# -- this supports reasoning for feature extraction and curl tightness

# %%
# apply Canny edge detection on sample images

# %%
# plot number of edge pixels per class

# %% [markdown]
# ## Texture Feature Exploration
#
# -- to show why texture matters and motivate feature extraction

# %% [markdown]
# ### Gabor Filter
# - show frequency and orietation patterns
# ---- curly texture produce unique responses

# %%
# show frequency and orientation patterns

# %% [markdown]
# ### Local Binary Patterns
# - lbp is good for strand texture

# %% [markdown]
# ### GLCM Metrics
# - contrast, homogeneity, energy, entropy

# %%
# contrast

# homogeneity

# energy

# entropy

# %% [markdown]
# ## Feature DataFrame Preview
#
# -- 40 random images for preview
#
# image       label          curl_tightness        glcm contrast         density
#
# -- for technical details

# %% [markdown]
# ## Dimentionality Reduction Preview
#
#
# -- this will help prove that there is a possiblilty what i will do will work
#
# -- can show sepraretion between classes and potential subclutsters within images

# %%
# run PCA on preview dataset

# %%
# plot points colors by class (straight, wavy, curly, kinky)

# %% [markdown]
# ## Prepare Data for Classification (VGG16)

# %%
# image resize size

# %%
# train, val, and test split paths

# %%
# preprocess input
